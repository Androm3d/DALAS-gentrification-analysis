# %% [markdown]
# # Processing data for Random Forest and SHAP

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# # Data Processing: The Flexible Delta Approach
#
# This script prepares the data for a Random Forest model by converting "snapshots"
# into "change events".
# Logic:
# 1. Load data for all cities.
# 2. Calculate the Gentrification Gap (Gi) for every neighborhood/year.
# 3. Create 'Next Period' features to compare Year T vs Year T+n.
# 4. Calculate 'delta_t' (length of the time gap).
# 5. Define Target: Change in Gentrification Gap over delta_t.
# 6. Define Features: Initial state of the neighborhood at Year T.

# %% [markdown]
# ## Define Paths and features

# %%
# --- Configuration ---
BARCELONA_PATH = "../data/preprocessed/barcelona/barcelona_master_dataframe.csv"
PARIS_PATH = "../data/preprocessed/paris/paris_master_dataframe.csv"
MILAN_PATH = "../data/preprocessed/milan/panel_data_milan.csv"
OUTPUT_PATH = "../data/processed/modeling_dataframe_gentrification_gap.csv"

# Columns to keep for features (State at Time T)
FEATURE_COLS = [
    'population_density',
    'pct_higher_education',
    'pct_young_adults',
    'median_household_income',
    'median_price_per_m2', # Kept for reference, though Ranks are used for Target
    'median_rent_per_m2'
    ]

# %% [markdown]
# ## 1. Load and Merge Data

# %%
def load_and_prep(path, city_name):
    if not Path(path).exists():
        print(f"⚠️ Warning: {path} not found.")
        return None
    
    df = pd.read_csv(path)
    df['city'] = city_name
    
    # Standardize column names if necessary (Paris uses 'neighborhood_name' vs BCN 'neighborhood_id')
    # We ensure we have a common ID column
    if 'neighborhood_id' not in df.columns and 'neighborhood_name' in df.columns:
        df['neighborhood_id'] = df['neighborhood_name'] # Fallback
        
    keep_cols = ['neighborhood_id', 'year', 'city'] + FEATURE_COLS
    
    # Filter columns
    available_cols = [c for c in keep_cols if c in df.columns]
    return df[available_cols].copy()

def calculate_percentile_ranks(df):
    """
    Calculates Percentile Rank (0-1) for Housing (Price+Rent) and Income.
    """
    def get_rank(x):
        return x.rank(pct=True)

    # 1. Rank Sales Price (Pi_sales)
    df['sales_rank'] = df.groupby(['city', 'year'])['median_price_per_m2'].transform(get_rank)
    
    # 2. Rank Rent Price (Pi_rent) - Handle case where column might be missing/empty
    if 'median_rent_per_m2' in df.columns:
        df['rent_rank'] = df.groupby(['city', 'year'])['median_rent_per_m2'].transform(get_rank)
        
        # 3. Create Composite Housing Rank (Pi)
        # We average the two ranks. If rent is NaN, it ignores it (check your preference).
        # We fillna to ensure we don't lose rows if one metric is missing.
        df['price_rank'] = df[['sales_rank', 'rent_rank']].mean(axis=1)
        
        # Fallback: If 'rent_rank' was NaN, mean() handles it. 
        # If both are NaN, it remains NaN.
        # If you want to be strict: 
        df['price_rank'] = df['price_rank'].fillna(df['sales_rank'])
    else:
        # Fallback for cities without rent data
        df['price_rank'] = df['sales_rank']
    
    # 4. Rank Income (Ii)
    df['income_rank'] = df.groupby(['city', 'year'])['median_household_income'].transform(get_rank)
    
    return df

# %% [markdown]
# ## 2. Calculate Gentrification Gap ($G_i$)
#
# Formula: $G_i = Rank(P_i) - Rank(I_i)$
# **Crucial:** The ranking must be done **per city** and **per year**.
# We compare a neighborhood to its peers in the same city at the same time.

# %%
# --- Main Processing (Barcelona & Paris Only) ---

# 0. Configuration
# Ensure Rent is in the feature list so it gets Z-scored
FEATURE_COLS = [
    'population_density',
    'pct_higher_education',
    'pct_young_adults',
    'median_household_income',
    'median_price_per_m2', 
    'median_rent_per_m2',
    'is_rent_imputed',
    'is_price_imputed'        
]

# 1. Load Data
print("--- Loading Data ---")
df_bcn = load_and_prep(BARCELONA_PATH, "Barcelona")
df_par = load_and_prep(PARIS_PATH, "Paris")

# Only combine Barcelona and Paris for Gentrification Gap calculation
# (Milan is already processed and will be merged in the NEXT step/notebook)
master_df = pd.concat([df_bcn, df_par], ignore_index=True)

# 2. Calculate Gentrification Gap (The "Sales-Only" Logic)
print("\n--- Calculating Gentrification Gap (Gi) ---")

# A. Compute Ranks (Pi and Ii)
# This function calculates 'sales_rank' and 'rent_rank'
master_df = calculate_percentile_ranks(master_df)

# --- THE FIX: Force Price Rank to be SALES ONLY ---
# We overwrite the 'price_rank' (which might be an average) with strictly 'sales_rank'.
# This ensures the Target (Gi) is purely about Sales Affordability.
master_df['price_rank'] = master_df['sales_rank'] 
# --------------------------------------------------

# B. Compute Gap (Gi = Pi - Ii)
master_df['gentrification_gap'] = master_df['price_rank'] - master_df['income_rank']

# 3. Generate 4-Year Target (Delta Gap)
print("\n--- Generating 4-Year Target ---")
master_df['target_year'] = master_df['year'] + 4

# Self-Merge to find the Future Gap (G_t+4)
merged_df = master_df.merge(
    master_df[['neighborhood_id', 'year', 'gentrification_gap']], 
    left_on=['neighborhood_id', 'target_year'],
    right_on=['neighborhood_id', 'year'],
    suffixes=('', '_future'),
    how='inner' 
)

# Calculate Target: Change in Gap over 4 years
merged_df['target_delta_gap'] = merged_df['gentrification_gap_future'] - merged_df['gentrification_gap']

# 4. Z-Score Normalization (For Features only)
print("\n--- Applying Z-Scores to Features ---")
# This will now create 'z_median_rent_per_m2' because we added it to FEATURE_COLS
for col in FEATURE_COLS:
    if col in merged_df.columns:
        merged_df[f'z_{col}'] = merged_df.groupby(['city', 'year'])[col].transform(
            lambda x: (x - x.mean()) / x.std()
        )

# 5. Final Selection
final_cols = [
    'neighborhood_id', 'city', 'year',          # Metadata
    'price_rank', 'income_rank',                # The components (Sales Rank)
    'gentrification_gap',                       # The State at T (Gi)
    'target_delta_gap'                          # The Target (Change in Gi)
] + [f'z_{c}' for c in FEATURE_COLS if f'z_{c}' in merged_df.columns]

model_df = merged_df[final_cols].copy()
model_df.rename(columns={'year': 'start_year'}, inplace=True)

# 6. Save
print("\n--- Final Data Info ---")
print(model_df.groupby('city')['start_year'].count())
print("\nSample Rows:")
print(model_df[['neighborhood_id', 'start_year', 'price_rank', 'gentrification_gap', 'target_delta_gap']].head())

output_dir = Path(OUTPUT_PATH).parent
output_dir.mkdir(parents=True, exist_ok=True)
model_df.to_csv(OUTPUT_PATH, index=False)
print(f"\n✅ Saved Gentrification Gap dataframe to {OUTPUT_PATH}")
model_df
# Out:
# --- Loading Data ---
#
# --- Calculating Gentrification Gap (Gi) ---
#
# --- Generating 4-Year Target ---
#
# --- Applying Z-Scores to Features ---
#
# --- Final Data Info ---
# city
# Barcelona    365
# Paris         80
# Name: start_year, dtype: int64
#
# Sample Rows:
#   neighborhood_id  start_year  price_rank  gentrification_gap  \
# 0         BCN_1.0      2015.0    0.465753            0.328767
# 1         BCN_1.0      2016.0    0.506849            0.342466
# 2         BCN_1.0      2017.0    0.561644            0.397260
# 3         BCN_1.0      2018.0    0.863014            0.698630
# 4         BCN_1.0      2019.0    0.726027            0.561644
#
#    target_delta_gap
# 0          0.232877
# 1          0.136986
# 2          0.027397
# 3         -0.301370
# 4         -0.356164
#
# ✅ Saved Gentrification Gap dataframe to ../data/processed/modeling_dataframe_gentrification_gap.csv
#     neighborhood_id       city  start_year  price_rank  income_rank  \
# ...

# %% [markdown]
# ## Mix with Milan
# TODO: Review processing strategy to be more homogeneous accross the three cities

# %%
# --- REVISED MERGE & FEATURE ENGINEERING (Corrected) ---

# 1. Prepare Barcelona/Paris
# We use 'merged_df' from the previous step because it has the Raw Values AND the Target.
# We map the BCN/Paris column names to the 'Universal/Milan' schema.
column_mapping = {
    'neighborhood_id': 'NIL',
    'year': 'Anno',
    'median_price_per_m2': 'Estimated_Price',
    'median_household_income': 'Median_Income_Est',
    'population_density': 'Pop_density',
    # 'pct_young_adults': 'pct_young_adults', # Same name, no change needed
    'gentrification_gap': 'Gentrification_Gap',
    'target_delta_gap': 'Target_Delta_Gap',
    'median_rent_per_m2': 'Median_Rent_Est'
}

final_bcn_par = merged_df.rename(columns=column_mapping).copy()

# Filter to keep only the relevant columns before merging
keep_cols = [
    'NIL', 'Anno', 'city', 
    'Gentrification_Gap', 'Target_Delta_Gap',
    'Estimated_Price', 'Median_Income_Est', 'Pop_density',
    'pct_young_adults', 'Median_Rent_Est'
]
# Ensure we only select columns that actually exist (pct_higher_education might be there too)
keep_cols = [c for c in keep_cols if c in final_bcn_par.columns]
final_bcn_par = final_bcn_par[keep_cols]


# 2. Load Milan
# Ensure this path is correct relative to where you run the notebook
df_mil = pd.read_csv(MILAN_PATH)
df_mil['city'] = 'Milan'


# 3. Concatenate Universal DataFrame
# Now both dataframes have 'Estimated_Price', 'Anno', 'NIL', etc.
print(f"Merging BCN/PAR ({final_bcn_par.shape}) with Milan ({df_mil.shape})...")
universal_df = pd.concat([final_bcn_par, df_mil], ignore_index=True)


# 4. UNIFIED Z-SCORE CALCULATION
# We calculate Z-scores on the combined dataset to ensure consistent handling.
z_score_map = {
    'Pop_density': 'Density_Z',
    'pct_young_adults': 'Young_Adults_Z',
    'Estimated_Price': 'Price_Z',
    'Median_Income_Est': 'Income_Z',
    'Median_Rent_Est': 'Rent_Z'
}

print("--- Generating Unified Z-Scores ---")
for raw_col, z_col in z_score_map.items():
    if raw_col in universal_df.columns:
        # Calculate Z-score grouped by City and Year
        universal_df[z_col] = universal_df.groupby(['city', 'Anno'])[raw_col].transform(
            lambda x: (x - x.mean()) / x.std()
        )
    else:
        print(f"⚠️ Warning: {raw_col} missing. Cannot calculate {z_col}")


# 5. Final Selection & Save
final_cols = [
    'NIL', 'Anno', 'city', 
    'Gentrification_Gap', 'Target_Delta_Gap',
    'Price_Z', 'Income_Z', 'Density_Z', 'Young_Adults_Z', 'Rent_Z'
]
# Add raw columns for reference/debugging
final_cols += ['Estimated_Price', 'Median_Income_Est']

# Safe selection
final_cols = [c for c in final_cols if c in universal_df.columns]
universal_df = universal_df[final_cols]

print(f"Final Universal Shape: {universal_df.shape}")
print(universal_df.groupby('city')['Anno'].count())

universal_df.to_csv("../data/processed/modeling_dataframe_universal.csv", index=False)
print("✅ Saved universal dataframe.")
# Out:
# Merging BCN/PAR ((445, 10)) with Milan ((425, 12))...
# --- Generating Unified Z-Scores ---
# Final Universal Shape: (870, 12)
# city
# Barcelona    365
# Milan        425
# Paris         80
# Name: Anno, dtype: int64
# ✅ Saved universal dataframe.
