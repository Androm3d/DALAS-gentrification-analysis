# %%
import pandas as pd
from pathlib import Path
import geopandas as gpd
import numpy as np
from functools import reduce
from sklearn.impute import KNNImputer   # for spatial interpolation
from sklearn.linear_model import LinearRegression   # for regression-based imputation

# %% [markdown]
# ## Merge Barcelona info into time series

# %%
def merge_csv_per_year(name, yearStart, yearEnd, input_dir, output_path=None, verbose=True):
    """
    Merge yearly files named {year}_{name}.csv for years 2015-2025
    into a single CSV named yearStart-yearEnd_{name}.csv by default.

    Parameters:
    - input_dir: path to the folder containing the yearly CSVs (string or Path)
    - output_path: optional path (string or Path) for the merged CSV file
    - verbose: print progress/messages if True

    Returns:
    - pandas.DataFrame with the concatenated data
    """
    input_dir = Path(input_dir)
    years = range(yearStart, yearEnd + 1)
    dfs = []
    for y in years:
        fp = input_dir / f"{y}_{name}.csv"
        if fp.exists():
            try:
                df = pd.read_csv(fp)
                df = df.iloc[:, 1:]     # Drop first column since it's a date 
                df['year'] = y
                dfs.append(df)
                if verbose:
                    print(f"Loaded: {fp.name} ({len(df)} rows)")
            except Exception as e:
                if verbose:
                    print(f"Failed to read {fp}: {e}")
        else:
            if verbose:
                print(f"Missing: {fp.name}")
    if not dfs:
        raise FileNotFoundError("No input files found for 2015-2025 in " + str(input_dir))
    out_df = pd.concat(dfs, ignore_index=True, sort=False)
    out_path = Path(output_path) if output_path else input_dir / f"{yearStart}-{yearEnd}_{name}.csv"
    out_df.to_csv(out_path, index=False)
    if verbose:
        print(f"Saved merged CSV to: {out_path} ({len(out_df)} total rows)")
    return out_df

# %%
merge_csv_per_year(name="pad_mdbas_niv-educa-esta_sexe", yearStart=2015, yearEnd=2025, input_dir="../data/raw/barcelona", output_path="../data/preprocessed/barcelona/2018-2025_pad_mdbas_niv-educa-esta_sexe.csv", verbose=True)
# Out:
# Loaded: 2015_pad_mdbas_niv-educa-esta_sexe.csv (12797 rows)
# Loaded: 2016_pad_mdbas_niv-educa-esta_sexe.csv (12779 rows)
# Loaded: 2017_pad_mdbas_niv-educa-esta_sexe.csv (12780 rows)
# Loaded: 2018_pad_mdbas_niv-educa-esta_sexe.csv (12769 rows)
# Loaded: 2019_pad_mdbas_niv-educa-esta_sexe.csv (12761 rows)
# Loaded: 2020_pad_mdbas_niv-educa-esta_sexe.csv (12750 rows)
# Loaded: 2021_pad_mdbas_niv-educa-esta_sexe.csv (12730 rows)
# Loaded: 2022_pad_mdbas_niv-educa-esta_sexe.csv (12709 rows)
# Loaded: 2023_pad_mdbas_niv-educa-esta_sexe.csv (12687 rows)
# Loaded: 2024_pad_mdbas_niv-educa-esta_sexe.csv (11274 rows)
# Loaded: 2025_pad_mdbas_niv-educa-esta_sexe.csv (12032 rows)
# Saved merged CSV to: ../data/preprocessed/barcelona/2018-2025_pad_mdbas_niv-educa-esta_sexe.csv (138068 total rows)
#         Codi_Districte Nom_Districte  Codi_Barri            Nom_Barri  AEB  \
# 0                    1  Ciutat Vella           1             el Raval    1
# ...

# %%
merge_csv_per_year(name="atles_renda_bruta_llar", yearStart=2015, yearEnd=2023, input_dir="../data/raw/barcelona", output_path="../data/preprocessed/barcelona/2018-2025_atles_renda_bruta_llar.csv", verbose=True)
# Out:
# Loaded: 2015_atles_renda_bruta_llar.csv (1068 rows)
# Loaded: 2016_atles_renda_bruta_llar.csv (1068 rows)
# Loaded: 2017_atles_renda_bruta_llar.csv (1068 rows)
# Loaded: 2018_atles_renda_bruta_llar.csv (1068 rows)
# Loaded: 2019_atles_renda_bruta_llar.csv (1068 rows)
# Loaded: 2020_atles_renda_bruta_llar.csv (1068 rows)
# Loaded: 2021_atles_renda_bruta_llar.csv (1068 rows)
# Loaded: 2022_atles_renda_bruta_llar.csv (1068 rows)
# Loaded: 2023_atles_renda_bruta_llar.csv (1068 rows)
# Saved merged CSV to: ../data/preprocessed/barcelona/2018-2025_atles_renda_bruta_llar.csv (9612 total rows)
#       Codi_Districte Nom_Districte  Codi_Barri  \
# 0                  1  Ciutat Vella           1
# 1                  1  Ciutat Vella           1
# 2                  1  Ciutat Vella           1
# 3                  1  Ciutat Vella           1
# 4                  1  Ciutat Vella           1
# ...              ...           ...         ...
# 9607              10    Sant Martí          73
# ...

# %%
merge_csv_per_year(name="pad_mdba_sexe_edat-1", yearStart=2015, yearEnd=2025, input_dir="../data/raw/barcelona", output_path="../data/preprocessed/barcelona/2018-2025-pad_mdba_sexe_edat-1.csv", verbose=True)
# Out:
# Loaded: 2015_pad_mdba_sexe_edat-1.csv (45794 rows)
# Loaded: 2016_pad_mdba_sexe_edat-1.csv (45834 rows)
# Loaded: 2017_pad_mdba_sexe_edat-1.csv (45914 rows)
# Loaded: 2018_pad_mdba_sexe_edat-1.csv (45936 rows)
# Loaded: 2019_pad_mdba_sexe_edat-1.csv (46006 rows)
# Loaded: 2020_pad_mdba_sexe_edat-1.csv (46086 rows)
# Loaded: 2021_pad_mdba_sexe_edat-1.csv (46080 rows)
# Loaded: 2022_pad_mdba_sexe_edat-1.csv (46110 rows)
# Loaded: 2023_pad_mdba_sexe_edat-1.csv (46149 rows)
# Loaded: 2024_pad_mdba_sexe_edat-1.csv (46162 rows)
# Loaded: 2025_pad_mdba_sexe_edat-1.csv (46231 rows)
# Saved merged CSV to: ../data/preprocessed/barcelona/2018-2025-pad_mdba_sexe_edat-1.csv (506302 total rows)
#         Codi_Districte Nom_Districte  Codi_Barri            Nom_Barri  AEB  \
# 0                    1  Ciutat Vella           1             el Raval    1
# 1                    1  Ciutat Vella           1             el Raval    1
# ...

# %% [markdown]
# # Export Barcelona geometric data to GeoJSON

# %%
gdf = gpd.read_file("../data/raw/barcelona/BCN_UNITATS_ADM/0301040100_Barris_UNITATS_ADM.shp")
gdf = gdf.to_crs(epsg=4326) # epsg 4326 = WGS84 standard for lat/lon
# Save to GeoJSON
gdf.to_file("../data/preprocessed/barcelona/barcelona_neighborhoods.geojson", driver="GeoJSON")

# %% [markdown]
# # Load and Inspect Preprocessed Data

# %%
# Load the datasets
try:
    property_values_df = pd.read_csv('../data/raw/barcelona/Taula estadística - Preu mitjà per superfície (€_m²) dels habitatges transmesos per compravenda/Taula estadística.csv')
    property_values_registered_df = pd.read_csv('../data/raw/barcelona/Taula estadística - Preu mitjà per superfície (€_m²) de les compravendes d’habitatge registrades per estat/Taula estadística.csv')
    rent_values_df = pd.read_csv('../data/raw/barcelona/Taula estadística - Preu mitjà per superfície (€_m²) del lloguer d\'habitatges/Taula estadística.csv')
    income_df = pd.read_csv('../data/preprocessed/barcelona/2018-2025_atles_renda_bruta_llar.csv')
    studies_df = pd.read_csv('../data/preprocessed/barcelona/2018-2025_pad_mdbas_niv-educa-esta_sexe.csv')
    age_df = pd.read_csv('../data/preprocessed/barcelona/2018-2025-pad_mdba_sexe_edat-1.csv')
    neighborhoods_gdf = gpd.read_file('../data/preprocessed/barcelona/barcelona_neighborhoods.geojson')
except FileNotFoundError as e:
    print(f"Error loading data: {e}. Please check your file paths.")
    exit(1)

# Initial Inspection
print("Property Values Info:")
property_values_df.info()
print("\nProperty Values Registered Info:")
property_values_registered_df.info()
print("\nRent Values Info:")
rent_values_df.info()
print("\nIncome Info:")
income_df.info()
print("\nStudies Info:")
studies_df.info()
print("\nAge and Population Distribution Info:")
age_df.info()
print("\nNeighborhoods GeoDataFrame Info:")
neighborhoods_gdf.info()

# Display first few rows to understand the content
print("\nProperty Values Head:")
print(property_values_df.head())
print("\nProperty Values Registered Head:")
print(property_values_registered_df.head())
print("\nRent Values Head:")
print(rent_values_df.head())
print("\nIncome Head:")
print(income_df.head())
print("\nStudies Head:")
print(studies_df.head())
print("\nAge and Population Distribution Head:")
print(age_df.head())
print("\nNeighborhoods Head:")
print(neighborhoods_gdf.head())
# Out:
# Property Values Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Territori           84 non-null     object
#  1   Tipus de territori  84 non-null     object
#  2   2012                84 non-null     object
#  3   2013                84 non-null     object
#  4   2014                84 non-null     object
#  5   2015                84 non-null     object
#  6   2016                84 non-null     object
#  7   2017                84 non-null     object
#  8   2018                84 non-null     object
#  9   2019                84 non-null     object
#  10  2020                84 non-null     object
#  11  2021                84 non-null     object
#  12  2022                84 non-null     object
#  13  2023                84 non-null     object
#  14  2024                84 non-null     object
# ...

# %% [markdown]
# ## Standardize Column Names & Clean 'Valor' Columns

# %%
def standardize_and_clean(df, valor_col='Valor'):
    # Standardize neighborhood and district codes/names
    df.rename(columns={
        'Codi_Districte': 'Codi_districte', 'Nom_Districte': 'Nom_districte',
        'Codi_Barri': 'Codi_barri', 'Nom_Barri': 'Nom_barri'
    }, inplace=True)
    # Convert 'Valor' from object to numeric, treating errors as NaN and filling with 0
    if valor_col in df.columns and df[valor_col].dtype == 'object':
        df[valor_col] = pd.to_numeric(df[valor_col], errors='coerce').fillna(0)
    return df

# 1. Standardize the "Reference" Dataframes first
income_df = standardize_and_clean(income_df, valor_col='Import_Renda_Bruta_€')
studies_df = standardize_and_clean(studies_df)
age_df = standardize_and_clean(age_df)

# 2. Create the Name -> ID Map
# We use income_df as the "Master List" of correct Names and IDs
name_to_id = income_df[['Nom_barri', 'Codi_barri']].drop_duplicates().set_index('Nom_barri')['Codi_barri']

def fix_price_df(df):
    
    # 3. Fix Property Values (Renaming & Mapping)
    if 'Territori' in df.columns:
        df.rename(columns={'Territori': 'Nom_barri'}, inplace=True)
        
    # Keep only "Tipus de territori" == "Barri"
    df = df[df['Tipus de territori'] == 'Barri'].copy()

    # --- MANUAL FIXES FOR BARCELONA OPEN DATA QUIRKS ---
    # We map the "weird" names in the Price file to the "standard" names in your Master list
    manual_corrections = {
        # The "AEI" suffixes are often added to these two neighborhoods in price datasets
        'el Poble Sec - AEI Parc Montjuïc': 'el Poble Sec',
        'el Poble Sec - AEI Parc de Montjuïc': 'el Poble Sec',
        'la Marina del Prat Vermell - AEI Zona Franca': 'la Marina del Prat Vermell',
        
        # "Sant Andreu" is both a District and a Neighborhood name. 
        # The dataset distinguishes them, but our map expects just "Sant Andreu" for the neighborhood.
        'Sant Andreu (Barri)': 'Sant Andreu',
        
        # Formatting differences (spaces/hyphens)
        'Sants - Badal': 'Sants-Badal',
        'Sant Gervasi - Galvany': 'Sant Gervasi- Galvany', 
        'Sant Gervasi - la Bonanova': 'Sant Gervasi- la Bonanova',
    }

    # Apply the corrections to the Name column first
    df['Nom_barri'] = df['Nom_barri'].replace(manual_corrections)

    # --- MAP TO IDS ---
    df['Codi_barri'] = df['Nom_barri'].map(name_to_id)

    # --- CLEANUP (DROP THE DISTRICTS/REGIONS) ---
    # Any row that is still NaN is a District (e.g., "Eixample") or Region ("Barcelona").
    # We drop them because we only want Neighborhood-level data.
    before_len = len(df)
    # show dropped rows
    # dropped_rows = df[df['Codi_barri'].isna()]
    # print("Dropped rows due to unmappable neighborhoods or districts:")
    # print(dropped_rows[['Nom_barri', 'Codi_barri']])

    df.dropna(subset=['Codi_barri'], inplace=True)
    dropped_count = before_len - len(df)

    # Convert ID to int for clean merging later
    df['Codi_barri'] = df['Codi_barri'].astype(int)

    print(f"✅ Mapped neighborhoods successfully.")
    print(f"🗑️ Dropped {dropped_count} rows (Districts, City totals, or unmappable regions).")
    
    return df

property_values_df = fix_price_df(property_values_df)
rent_values_df = fix_price_df(rent_values_df)
# Out:
# ✅ Mapped neighborhoods successfully.
# 🗑️ Dropped 0 rows (Districts, City totals, or unmappable regions).
# ✅ Mapped neighborhoods successfully.
# 🗑️ Dropped 0 rows (Districts, City totals, or unmappable regions).

# %% [markdown]
# ### Price imputation test
# This was a test to see if using market data instead of KNN for the feature median_price_per_m2 would improve R2. It did not.
# I also added linear regression since further checks (end of the notebook) showed a bit of differences in the real and market prices distributions:
# - Using only market data yielded R2 = -0.35
# - Plain filling yielded R2 = -0.02
# - Transformed with linear regression yielded R2 = +0.07 for
# - KNN on neighbors (instead of source imputation with market data, so using only real goverment data) yielded R2 = 0.35
#
# Best seems to be KNN and ignoring market data.

# %%
def smart_fill_prices_adaptive(reg_df, mkt_df, name_to_id_map):
    print("--- Running Adaptive Regression Fill ---")
    
    # 1. Helper to clean and melt (Same as before)
    def clean(df, source):
        df = df.copy()
        if 'Tipus de territori' in df.columns: df = df[df['Tipus de territori'] == 'Barri']
        if 'Territori' in df.columns: df.rename(columns={'Territori': 'Nom_barri'}, inplace=True)
        
        manual_corrections = {
             'el Poble Sec - AEI Parc Montjuïc': 'el Poble Sec',
             'Sant Andreu (Barri)': 'Sant Andreu',
             'Sants Badal': 'Sants-Badal',
             'Sant Gervasi Galvany': 'Sant Gervasi - Galvany'
        }
        df['Nom_barri'] = df['Nom_barri'].replace(manual_corrections)
        if 'Codi_barri' not in df.columns: df['Codi_barri'] = df['Nom_barri'].map(name_to_id_map)
        
        if source == 'reg':
            cols = [c for c in df.columns if 'tr ' in c]
            long = df.melt(id_vars=['Codi_barri'], value_vars=cols, value_name='Price')
            long['year'] = long['variable'].str.extract(r'(\d{4})').astype(float)
        else:
            cols = [c for c in df.columns if str(c).isdigit()]
            long = df.melt(id_vars=['Codi_barri'], value_vars=cols, var_name='year', value_name='Price')
            long['year'] = long['year'].astype(float)
            
        long['Price'] = pd.to_numeric(long['Price'], errors='coerce')
        return long.groupby(['Codi_barri', 'year'])['Price'].mean().reset_index()

    df_reg = clean(reg_df, 'reg')
    df_mkt = clean(mkt_df, 'mkt')
    
    # 2. Train the Adapter (Linear Regression)
    # We only use years where we have BOTH data to learn the relationship
    common = pd.merge(df_reg, df_mkt, on=['Codi_barri', 'year'], suffixes=('_reg', '_mkt')).dropna()
    
    X = common[['Price_mkt']] # Feature: Market Price
    y = common['Price_reg']   # Target: Real Price
    
    model = LinearRegression()
    model.fit(X, y)
    
    r2 = model.score(X, y)
    print(f"Adaptive Model trained on {len(common)} overlaps.")
    print(f"Relationship R2: {r2:.4f}")
    print(f"Formula: Real = {model.intercept_:.2f} + {model.coef_[0]:.4f} * Market")
    
    # 3. Apply Prediction to Missing Data
    # Merge everything
    final = pd.merge(df_reg, df_mkt, on=['Codi_barri', 'year'], suffixes=('_reg', '_mkt'), how='outer')
    
    # Identify rows needing fill (Reg is missing, Mkt exists)
    needs_fill = final['Price_reg'].isna() & final['Price_mkt'].notna()
    
    # Predict ONLY for those rows
    if needs_fill.sum() > 0:
        # We must reshape for sklearn
        X_missing = final.loc[needs_fill, ['Price_mkt']]
        predicted_real = model.predict(X_missing)
        
        # Fill
        final.loc[needs_fill, 'Price_reg'] = predicted_real
    
    # 4. Final Cleanup
    final['median_price_per_m2'] = final['Price_reg']
    final['is_price_imputed'] = needs_fill.astype(int)
    
    print(f"Filled {needs_fill.sum()} missing years using Adaptive Regression.")
    
    return final[['Codi_barri', 'year', 'median_price_per_m2', 'is_price_imputed']]

# Execute
median_price_per_m2 = smart_fill_prices_adaptive(property_values_registered_df, property_values_df, name_to_id)
# Out:
# --- Running Adaptive Regression Fill ---
# Adaptive Model trained on 782 overlaps.
# Relationship R2: 0.7947
# Formula: Real = 131.87 + 1.1469 * Market
# Filled 192 missing years using Adaptive Regression.

# %% [markdown]
# ### Aggregate only registered sales
# Since inputting marked data proved counter productive

# %%
def process_registered_only(df, name_to_id_map):
    print("--- Processing Registered Data (Used Homes Only) ---")
    
    # 1. Filter for Territory AND Used Housing
    # We RESTORE this filter to remove the noise from New Developments
    df = df[
        (df['Tipus de territori'] == 'Barri') & 
        (df['Règim'] == 'Habitatge usat')
    ].copy() 
    
    # 2. Fix Names & Map IDs
    manual_corrections = {
         'el Poble Sec - AEI Parc Montjuïc': 'el Poble Sec',
         'Sant Andreu (Barri)': 'Sant Andreu',
         'Sants Badal': 'Sants-Badal',
         'Sant Gervasi Galvany': 'Sant Gervasi - Galvany'
    }
    if 'Territori' in df.columns:
        df['Nom_barri'] = df['Territori'].replace(manual_corrections)
    
    df['Codi_barri'] = df['Nom_barri'].map(name_to_id_map)
    
    # 3. Melt Quarters
    q_cols = [c for c in df.columns if 'tr ' in c]
    df_long = df.melt(id_vars=['Codi_barri'], value_vars=q_cols, value_name='Price')
    
    # 4. Extract Year & Clean
    df_long['year'] = df_long['variable'].str.extract(r'(\d{4})').astype(float)
    df_long['Price'] = pd.to_numeric(df_long['Price'], errors='coerce')
    
    # 5. Aggregate
    df_yearly = df_long.groupby(['Codi_barri', 'year'])['Price'].mean().reset_index()
    df_yearly.rename(columns={'Price': 'median_price_per_m2'}, inplace=True)
    
    # It is safe to drop NaNs here because the Outer Merge later will bring 
    # the neighborhood back (with NaN price) for KNN to fix.
    df_yearly.dropna(subset=['median_price_per_m2'], inplace=True)
    
    print(f"Processed {len(df_yearly)} valid neighborhood-years (Used Only).")
    return df_yearly

# %% [markdown]
# ## Process Each Feature According to the Data Model

# %%
# A. Average Price per m2 (from unitary cadastral value) and Rent Values
def extract_price_features(df, column_name):
    # Melt to long format
    df_long = df.melt(id_vars=['Codi_barri', 'Nom_barri'], var_name='year', value_name='avg_price_per_m2')
    df_long['year'] = df_long['year'].astype(int)
    # rename median_price_per_m2 column.rename(columns={'avg_price_per_m2': 'median_price_per_m2'}, inplace=True)
    df_long.rename(columns={'avg_price_per_m2': column_name}, inplace=True)

    # replace - in the years columns with NaN
    df_long[column_name] = pd.to_numeric(df_long[column_name], errors='coerce')
    return df_long

rent_values_df = rent_values_df.drop(columns=[col for col in rent_values_df.columns if col not in ['Codi_barri', 'Nom_barri'] + [str(y) for y in range(2015, 2024)]])
median_rent_per_m2 = extract_price_features(rent_values_df, 'median_rent_per_m2')

median_price_per_m2 = smart_fill_prices_adaptive(property_values_registered_df, property_values_df, name_to_id)


# ignore market data for now (see explanation in smart_fill_prices_adaptive)
median_price_per_m2.loc[
    median_price_per_m2['is_price_imputed'] == 1, 
    'median_price_per_m2'
] = np.nan
# median_price_per_m2 = process_registered_only(property_values_registered_df, name_to_id)

# B. Median Household Income
median_household_income = income_df.groupby(['Codi_barri', 'year'])['Import_Renda_Bruta_€'].median().reset_index()
median_household_income.rename(columns={'Import_Renda_Bruta_€': 'median_household_income'}, inplace=True)

# C. Percentage Higher Education
# First, get total population from the studies dataset
total_pop_studies = studies_df.groupby(['Codi_barri', 'year'])['Valor'].sum().reset_index()
total_pop_studies.rename(columns={'Valor': 'total_population_studies'}, inplace=True)
# Then, get population with higher education (levels 5 and 6)
higher_edu_pop = studies_df[studies_df['NIV_EDUCA_esta'].isin([5, 6])]
higher_edu_counts = higher_edu_pop.groupby(['Codi_barri', 'year'])['Valor'].sum().reset_index()
higher_edu_counts.rename(columns={'Valor': 'population_higher_education'}, inplace=True)
# Merge and calculate percentage
education_features = pd.merge(total_pop_studies, higher_edu_counts, on=['Codi_barri', 'year'])
education_features['pct_higher_education'] = (education_features['population_higher_education'] / education_features['total_population_studies']) * 100

# D. Population Density and Percentage of Young Adults (from the Age dataset)
# Get total population
total_population = age_df.groupby(['Codi_barri', 'year'])['Valor'].sum().reset_index()
total_population.rename(columns={'Valor': 'total_population'}, inplace=True)
# Get young adult population (ages 20-39 inclusive)
young_adults_pop = age_df[age_df['EDAT_1'].between(20, 39)]
young_adult_counts = young_adults_pop.groupby(['Codi_barri', 'year'])['Valor'].sum().reset_index()
young_adult_counts.rename(columns={'Valor': 'young_adult_population'}, inplace=True)
# Merge population features together
population_features = pd.merge(total_population, young_adult_counts, on=['Codi_barri', 'year'])
# Calculate pct_young_adults
population_features['pct_young_adults'] = (population_features['young_adult_population'] / population_features['total_population']) * 100

std_household_income = income_df.groupby(['Codi_barri', 'year'])['Import_Renda_Bruta_€'].std().reset_index()
std_household_income.rename(columns={'Import_Renda_Bruta_€': 'std_household_income'}, inplace=True)

median_price_per_m2

median_rent_per_m2
# Out:
# --- Running Adaptive Regression Fill ---
# Adaptive Model trained on 782 overlaps.
# Relationship R2: 0.7947
# Formula: Real = 131.87 + 1.1469 * Market
# Filled 192 missing years using Adaptive Regression.
#      Codi_barri                                     Nom_barri  year  \
# 0             1                                      el Raval  2015
# 1             2                                el Barri Gòtic  2015
# 2             3                                la Barceloneta  2015
# 3             4         Sant Pere, Santa Caterina i la Ribera  2015
# 4             5                                 el Fort Pienc  2015
# ..          ...                                           ...   ...
# 643          69  Diagonal Mar i el Front Marítim del Poblenou  2023
# 644          70                         el Besòs i el Maresme  2023
# 645          71                       Provençals del Poblenou  2023
# 646          72                      Sant Martí de Provençals  2023
# ...

# %% [markdown]
# ## Handle Geospatial Data (for population density)

# %%
# Load the CORRECT shapefile directly
neighborhoods_gdf = gpd.read_file("../data/raw/barcelona/BCN_UNITATS_ADM/0301040100_Barris_UNITATS_ADM.shp")

# --- Simplified Geospatial Processing ---

# STEP 1: Rename the 'BARRI' column to 'Codi_barri' for consistency
neighborhoods_gdf.rename(columns={'BARRI': 'Codi_barri'}, inplace=True)

# STEP 2: Robustly convert the neighborhood code to integer
neighborhoods_gdf['Codi_barri'] = pd.to_numeric(neighborhoods_gdf['Codi_barri'], errors='coerce')
neighborhoods_gdf.dropna(subset=['Codi_barri'], inplace=True)
neighborhoods_gdf['Codi_barri'] = neighborhoods_gdf['Codi_barri'].astype(int)

# STEP 3: Proceed with the area calculation
neighborhoods_gdf_proj = neighborhoods_gdf.to_crs(epsg=25831)
neighborhoods_gdf['area_km2'] = neighborhoods_gdf_proj.geometry.area / 1_000_000

# STEP 4: Merge with population data
# We use the cleaned 'neighborhoods_gdf' which is now our main geo-dataframe
population_features = pd.merge(population_features, neighborhoods_gdf[['Codi_barri', 'area_km2']], on='Codi_barri')
population_features['population_density'] = population_features['total_population'] / population_features['area_km2']

# %% [markdown]
# ## Mix everything

# %%
feature_dfs = [
    median_household_income,
    median_price_per_m2,
    median_rent_per_m2,
    education_features[['Codi_barri', 'year', 'pct_higher_education']],
    population_features[['Codi_barri', 'year', 'population_density', 'pct_young_adults']],
    std_household_income
]

# %% [markdown]
# # Assemble the Master DataFrame
# ### Also KNN spatial interpolation
# Some neighborhoods have seen no sales on given years, we use KNN to interpolate the sale prices

# %%
from functools import reduce
from sklearn.impute import KNNImputer

# 1. MERGE (Use 'outer' to keep rows with missing data so we can fix them)
#    If you use 'inner', a missing Price in 2015 might delete the Income data for 2015 too!
master_df = reduce(lambda left, right: pd.merge(left, right, on=['Codi_barri', 'year'], how='outer'), feature_dfs)

# Keep only years 2015-2023
master_df = master_df[(master_df['year'] >= 2015) & (master_df['year'] <= 2023)]

# 2. METADATA & GEOMETRY
master_df['city'] = 'Barcelona'
master_df = pd.merge(master_df, neighborhoods_gdf[['Codi_barri', 'NOM', 'geometry']], on='Codi_barri', how='left')

# 3. RENAMING (Standardize IDs)
master_df.rename(columns={'NOM': 'neighborhood_name', 'Codi_barri': 'neighborhood_id'}, inplace=True)
master_df['neighborhood_id'] = 'BCN_' + master_df['neighborhood_id'].astype(str)

# ==============================================================================
# [UPGRADED STEP 4] MULTI-TARGET IMPUTATION (PRICE & RENT)
# ==============================================================================
print("--- Starting Imputation ---")

# 1. Define targets to fix
targets = ['median_price_per_m2', 'median_rent_per_m2']
predictors = ['median_household_income'] # The 'anchor' variable that is never missing

# 2. Sort for Temporal Interpolation
master_df = master_df.sort_values(['neighborhood_id', 'year'])

# 3. Process each target (Flag + Temporal Fill)
for col in targets:
    # A. Create Flag
    # 1 = Interpolated, 0 = Real
    master_df[f'is_{col}_imputed'] = master_df[col].isnull().astype(int)
    
    # B. Temporal Interpolation (History fill)
    # Fills gaps like: 2015 (10) -> 2016 (NaN) -> 2017 (12) ===> 2016 becomes 11
    master_df[col] = master_df.groupby('neighborhood_id')[col].transform(
        lambda x: x.interpolate(method='linear', limit_direction='both')
    )
    

# 4. Multivariate Imputation (KNN)
# We feed [Income, Price, Rent] into the imputer.
# It uses WHATEVER is available to guess what is missing.
impute_cols = predictors + targets 
imputed_dfs = []

print(f"Running KNN Imputation on: {targets}")

for year in master_df['year'].unique():
    year_data = master_df[master_df['year'] == year].copy()
    
    # Check if we have ANY missing data in our targets for this year
    if year_data[targets].isnull().sum().sum() > 0:
        
        # Check if we have enough data to run KNN (need at least 1 valid row)
        # We check if 'median_household_income' is present (it should be!)
        if year_data['median_household_income'].notna().sum() > 5:
            
            imputer = KNNImputer(n_neighbors=5, weights='uniform')
            
            # FIT & TRANSFORM
            # This returns a numpy array with filled values
            filled_data = imputer.fit_transform(year_data[impute_cols])
            
            # UPDATE DATAFRAME
            # The output columns match 'impute_cols' order.
            # Index 0 is Income, Index 1 is Price, Index 2 is Rent (based on list above)
            for i, col in enumerate(impute_cols):
                year_data[col] = filled_data[:, i]
                
        else:
            print(f"⚠️ Critical: Year {year} has insufficient data for KNN. Skipping.")
            
    imputed_dfs.append(year_data)
    
# 5. Reassemble
master_df = pd.concat(imputed_dfs).sort_values(['neighborhood_id', 'year'])


'''
# [REPLACEMENT FOR STEP 4: DROP INSTEAD OF IMPUTE]
print(f"Rows before dropping missing prices: {len(master_df)}")

# Critical: Drop rows where we have no Real Price.
# We do NOT want to rank "Ghost" neighborhoods.
master_df.dropna(subset=['median_price_per_m2'], inplace=True)

print(f"Rows after dropping ghosts: {len(master_df)}")

'''

# 6. Final Safety Check (City Mean Fallback)
# If KNN failed (e.g., a year where NO neighborhood has Rent), fill with global mean
for col in targets:
    remaining_nan = master_df[col].isnull().sum()
    if remaining_nan > 0:
        print(f"⚠️ {col} still has {remaining_nan} missing values. Filling with global mean.")
        master_df[col] = master_df[col].fillna(master_df[col].mean())

print(f"✅ Imputation Complete.")
print(f"Final Missing Price: {master_df['median_price_per_m2'].isnull().sum()}")
print(f"Final Missing Rent:  {master_df['median_rent_per_m2'].isnull().sum()}")

# 5. FINAL DISPLAY & SAVE
print("\n--- Master DataFrame Info ---")
master_df.info()
print("\n--- Master DataFrame Head ---")
print(master_df.head())

master_df.to_csv("../data/preprocessed/barcelona/barcelona_master_dataframe.csv", index=False)
# Out:
# --- Starting Imputation ---
# Running KNN Imputation on: ['median_price_per_m2', 'median_rent_per_m2']
# ✅ Imputation Complete.
# Final Missing Price: 0
# Final Missing Rent:  0
#
# --- Master DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 657 entries, 0 to 80
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighborhood_id                 657 non-null    object
#  1   year                            657 non-null    float64
#  2   median_household_income         657 non-null    float64
#  3   median_price_per_m2             657 non-null    float64
#  4   is_price_imputed                648 non-null    float64
#  5   Nom_barri                       648 non-null    object
#  6   median_rent_per_m2              657 non-null    float64
#  7   pct_higher_education            657 non-null    float64
# ...

# %%
# print amount of interpolated vs observed data for median_price_per_m2
imputed_counts = master_df['is_median_price_per_m2_imputed'].value_counts()
print("\nMedian Price per m2 Data Status Counts:")
print(imputed_counts)
# Out:
# Median Price per m2 Data Status Counts:
# is_median_price_per_m2_imputed
# 0    595
# 1     62
# Name: count, dtype: int64

# %% [markdown]
# ## Debug market vs government registered prices

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

def diagnose_price_mismatch(reg_df, mkt_df, name_to_id_map):
    print("--- Starting Diagnosis ---")
    
    # --- HELPER: Smart Preprocessing ---
    def prepare_df(df, source_type):
        df = df.copy()
        
        # 1. Handle "Tipus de territori" (If it exists, filter it. If not, assume already filtered)
        if 'Tipus de territori' in df.columns:
            df = df[df['Tipus de territori'] == 'Barri'].copy()
        
        # 2. Handle Name Column (Raw 'Territori' vs Clean 'Nom_barri')
        if 'Territori' in df.columns:
            df.rename(columns={'Territori': 'Nom_barri'}, inplace=True)
            
        # 3. Clean Names (Apply corrections if needed)
        manual_corrections = {
             'el Poble Sec - AEI Parc Montjuïc': 'el Poble Sec',
             'Sant Andreu (Barri)': 'Sant Andreu',
             'Sants Badal': 'Sants-Badal',
             'Sant Gervasi Galvany': 'Sant Gervasi - Galvany'
        }
        df['Nom_barri'] = df['Nom_barri'].replace(manual_corrections)
        
        # 4. Ensure ID exists
        if 'Codi_barri' not in df.columns:
             df['Codi_barri'] = df['Nom_barri'].map(name_to_id_map)
        
        # 5. MELT (Wide to Long)
        if source_type == 'registered':
            # Identify quarter columns (e.g., '1r tr 2014')
            val_cols = [c for c in df.columns if 'tr ' in c]
            df_long = df.melt(id_vars=['Codi_barri'], value_vars=val_cols, value_name='Price')
            # Extract Year from string "1r tr 2014"
            df_long['year'] = df_long['variable'].str.extract(r'(\d{4})').astype(float)
        else:
            # Identify year columns (digits only, like '2015')
            val_cols = [c for c in df.columns if str(c).isdigit()]
            df_long = df.melt(id_vars=['Codi_barri'], value_vars=val_cols, var_name='year', value_name='Price')
            df_long['year'] = df_long['year'].astype(float)
            
        # 6. Clean Numerics (Crucial fix for "String Sum" error)
        df_long['Price'] = pd.to_numeric(df_long['Price'], errors='coerce')
        
        # 7. Aggregate to Yearly Mean
        return df_long.groupby(['Codi_barri', 'year'])['Price'].mean().reset_index()

    # --- EXECUTE ---
    reg_yearly = prepare_df(reg_df, 'registered')
    mkt_yearly = prepare_df(mkt_df, 'market')
    
    # --- MERGE & ANALYZE ---
    merged = pd.merge(reg_yearly, mkt_yearly, on=['Codi_barri', 'year'], suffixes=('_Reg', '_Mkt'), how='inner')
    
    # Drop NaNs
    valid_data = merged.dropna(subset=['Price_Reg', 'Price_Mkt'])
    
    if len(valid_data) > 0:
        corr, _ = pearsonr(valid_data['Price_Reg'], valid_data['Price_Mkt'])
        valid_data['Gap_Pct'] = (valid_data['Price_Mkt'] - valid_data['Price_Reg']) / valid_data['Price_Reg'] * 100
        
        print(f"\n--- REPORT ---")
        print(f"Data Points: {len(valid_data)}")
        print(f"Correlation: {corr:.4f}")
        print(f"Avg Gap (Market > Real): {valid_data['Gap_Pct'].mean():.2f}%")
        print(f"Gap Volatility (Std Dev): {valid_data['Gap_Pct'].std():.2f}%")
        
        # Visualization
        plt.figure(figsize=(10, 5))
        
        # Plot 1: Scatter
        plt.subplot(1, 2, 1)
        sns.scatterplot(data=valid_data, x='Price_Reg', y='Price_Mkt', alpha=0.5)
        max_val = max(valid_data['Price_Reg'].max(), valid_data['Price_Mkt'].max())
        plt.plot([0, max_val], [0, max_val], 'r--', label="Identity")
        plt.title("Real (X) vs Market (Y)")
        
        # Plot 2: Trajectories
        plt.subplot(1, 2, 2)
        for bid in valid_data['Codi_barri'].unique()[:3]: # Show first 3 neighborhoods
            subset = valid_data[valid_data['Codi_barri'] == bid].sort_values('year')
            plt.plot(subset['year'], subset['Price_Reg'], label=f"Reg {bid}")
            plt.plot(subset['year'], subset['Price_Mkt'], linestyle='--', label=f"Mkt {bid}")
        plt.title("Trends (Solid=Real, Dashed=Market)")
        plt.legend()
        plt.tight_layout()
        plt.show()
    else:
        print("⚠️ No overlapping data found (Check if years or IDs match).")
    
    return merged

# Run with your existing dataframes
comparison = diagnose_price_mismatch(property_values_registered_df, property_values_df, name_to_id)
# Out:
# --- Starting Diagnosis ---
#
# --- REPORT ---
# Data Points: 782
# Correlation: 0.8915
# Avg Gap (Market > Real): -13.83%
# Gap Volatility (Std Dev): 15.02%
# /var/folders/1t/rhx43jps20b01lf6bnvdgsgm0000gp/T/ipykernel_87945/3008925339.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_data['Gap_Pct'] = (valid_data['Price_Mkt'] - valid_data['Price_Reg']) / valid_data['Price_Reg'] * 100

# %%
# Check which years are being imputed
print(median_price_per_m2[median_price_per_m2['is_price_imputed'] == 1]['year'].value_counts().sort_index())
# Out:
# year
# 2012.0    67
# 2013.0    67
# 2014.0     5
# 2015.0     5
# 2016.0     4
# 2017.0     5
# 2018.0     4
# 2019.0     5
# 2020.0     5
# 2021.0     5
# 2022.0     6
# 2023.0     4
# 2024.0     5
# 2025.0     5
# Name: count, dtype: int64
